# %%
from opendbc.car import structs
from opendbc.car.honda.values import CAR

TEST_PLATFORMS = set(CAR)

print(f"Test set contains {len(TEST_PLATFORMS)} qualifying platforms:")
for platform in TEST_PLATFORMS:
  print(f"{platform}")
# Out:
# Test set contains 23 qualifying platforms:
# HONDA_CRV
# HONDA_ODYSSEY_CHN
# ACURA_ILX
# HONDA_E
# HONDA_CIVIC_BOSCH
# ACURA_RDX_3G
# HONDA_HRV
# HONDA_INSIGHT
# HONDA_ODYSSEY
# ACURA_RDX
# HONDA_FREED
# HONDA_CIVIC
# HONDA_FIT
# HONDA_CIVIC_2022
# HONDA_CRV_5G
# HONDA_ACCORD
# HONDA_CRV_EU
# HONDA_RIDGELINE
# HONDA_CRV_HYBRID
# HONDA_CIVIC_BOSCH_DIESEL
# HONDA_PILOT
# HONDA_PILOT_4G
# HONDA_HRV_3G

# %%
import random

from openpilot.tools.lib.logreader import LogReader
from openpilot.tools.lib.comma_car_segments import get_comma_car_segments_database

database = get_comma_car_segments_database()
TEST_SEGMENTS = []

MAX_SEGS_PER_PLATFORM = 5  # TODO: Increase this to search more segments

print("Collecting segments from commaCarSegments dataset:\n")
for platform in TEST_PLATFORMS:
  # assert(platform in database)
  if platform not in database:
    print(f"Skipping platform: {platform}, no data available")
    continue
  
  all_segments = database[platform]

  NUM_SEGMENTS = min(len(all_segments), MAX_SEGS_PER_PLATFORM)

  print(f"Got {len(all_segments)} segments for platform {platform}, sampling {NUM_SEGMENTS} segments")

  segment_subset = random.sample(all_segments, NUM_SEGMENTS)
  for segment in segment_subset:
    TEST_SEGMENTS.append([platform, segment])

print(f"\nSampled {len(TEST_SEGMENTS)} segments from commaCarSegments")

# For new car port development, not yet upstream
EXTRA_SEGMENTS = [
  ["ACURA_MDX_4G", "f9c43864cf057d05|2024-01-15--23-01-20/0"],  # CAN-FD
  ["ACURA_INTEGRA", "3f8ae015ce70365f/00000003--a22590d0e4/0"],
  ["HONDA_CITY", "56b2cf1dacdcd033/00000048--3267801001/0"],
  # ["HONDA_ODYSSEY_5G_MMR", "558ac87ada6a88cd/00000036--7d59e2af08/0"],  # no rlogs
  ["ACURA_MDX_4G_MMR", "ad9840558640c31d/0000001a--d6cd4871c2/0"],  # CAN-FD
  ["ACURA_RDX_3G_MMR", "0416c2843c0bfc91/0000001d--59c7744d87/0"],
  ["HONDA_NBOX", "414af83891dbf72c/00000006--51fa6d99cd/0"],
]

TEST_SEGMENTS.extend(EXTRA_SEGMENTS)

print(f"Added {len(EXTRA_SEGMENTS)} manual segments")
# Out:
# Collecting segments from commaCarSegments dataset:
#
# Got 156 segments for platform HONDA_CRV, sampling 5 segments
# Skipping platform: HONDA_ODYSSEY_CHN, no data available
# Got 4 segments for platform ACURA_ILX, sampling 4 segments
# Got 2 segments for platform HONDA_E, sampling 2 segments
# Got 12 segments for platform HONDA_CIVIC_BOSCH, sampling 5 segments
# Got 747 segments for platform ACURA_RDX_3G, sampling 5 segments
# Got 150 segments for platform HONDA_HRV, sampling 5 segments
# Got 661 segments for platform HONDA_INSIGHT, sampling 5 segments
# Got 19 segments for platform HONDA_ODYSSEY, sampling 5 segments
# Got 147 segments for platform ACURA_RDX, sampling 5 segments
# Got 50 segments for platform HONDA_FREED, sampling 5 segments
# Got 1483 segments for platform HONDA_CIVIC, sampling 5 segments
# Got 282 segments for platform HONDA_FIT, sampling 5 segments
# Got 1341 segments for platform HONDA_CIVIC_2022, sampling 5 segments
# Got 3836 segments for platform HONDA_CRV_5G, sampling 5 segments
# Got 16 segments for platform HONDA_ACCORD, sampling 5 segments
# Skipping platform: HONDA_CRV_EU, no data available
# Got 50 segments for platform HONDA_RIDGELINE, sampling 5 segments
# Got 359 segments for platform HONDA_CRV_HYBRID, sampling 5 segments
# Skipping platform: HONDA_CIVIC_BOSCH_DIESEL, no data available
# Got 3239 segments for platform HONDA_PILOT, sampling 5 segments
# Got 2 segments for platform HONDA_PILOT_4G, sampling 2 segments
# Got 60 segments for platform HONDA_HRV_3G, sampling 5 segments
#
# Sampled 93 segments from commaCarSegments
# Added 6 manual segments

# %%
import copy
from math import isclose
import matplotlib.pyplot as plt
import numpy as np

from opendbc.can.parser import CANParser
from opendbc.car.honda.values import DBC
from opendbc.car.honda.hondacan import CanBus

from openpilot.selfdrive.pandad import can_capnp_to_list
from openpilot.tools.lib.logreader import LogReader

door_address = 1029
position_addresses = [392, 401, 419]
mt_address = 477
scm_addresses = [660, 806, 422, 662]
all_addresses = [*position_addresses, *scm_addresses, mt_address, door_address]
buses = [0, 1]

car_results = {}
for segment in TEST_SEGMENTS:
  car_results[segment[0]] = {}
  for address in all_addresses:
    car_results[segment[0]][address] = 0

for segment in TEST_SEGMENTS:
  print(f"Analyzing segment {segment[1]:<44} for {segment[0]}")
  lr = LogReader(segment[1])
  CP = lr.first("carParams")
  if CP is None:
    continue


  segment_counts = {}
  gear_activity = {}
  for address in all_addresses:
    segment_counts[address] = 0
    gear_activity[address] = False
    
  can_msgs = [msg for msg in lr if msg.which() == "can"]
  for can_msg in can_msgs:
    for packet in can_msg.can:
      for address in all_addresses:
        if packet.src in buses and packet.address == address:
          if address == 392:
            assert len(packet.dat) == 6
            segment_counts[392] += 1
            if packet.dat[0] & 0x7F != 0:
              gear_activity[address] = True
          if address == 401:
            assert len(packet.dat) == 8
            segment_counts[401] += 1
            if packet.dat[3] & 0xF != 0:
              gear_activity[address] = True
          if address == 419:
            assert len(packet.dat) == 8
            segment_counts[419] += 1
            if packet.dat[3] & 0x7F != 0:
              gear_activity[address] = True
          if address == 422:
            # SCM_BUTTONS A
            assert len(packet.dat) == 8
            segment_counts[422] += 1
          if address == 477:
            # Only used for MT, but often present on non-MT cars, not as easy to detect gear activity
            assert len(packet.dat) == 8
            segment_counts[477] += 1
          if address == 660:
            # SCM_FEEDBACK A
            assert len(packet.dat) == 8
            segment_counts[660] += 1
          if address == 662:
            # SCM_BUTTONS B
            packetlen = len(packet.dat)
            if packetlen != 4:
              print(f"622 length {packetlen}")
            segment_counts[662] += 1
          if address == 806:
            # SCM_FEEDBACK B
            assert len(packet.dat) == 8
            segment_counts[806] += 1
          if address == 1029:
            assert len(packet.dat) == 8
            segment_counts[1029] += 1

  # Make sure gear position activity was found, or the MT message is present
  #print(segment_counts)
    
  gear_position_found = False
  for address in position_addresses:
    if segment_counts[address] > 0:
      frequency = round(segment_counts[address] / 60)
      if gear_activity[address]:
        #print(f"Found shifter position: GEARBOX_{address} at {frequency}Hz")
        #assert(address == 392 and isclose(frequency, 100, abs_tol=20) or \
        #       address == 401 and isclose(frequency, 100, abs_tol=20) or \
        #       address == 419 and isclose(frequency, 50, abs_tol=10))               
        car_results[segment[0]][address] += 1
        gear_position_found = True

  if not gear_position_found:
    address = mt_address
    frequency = round(segment_counts[address] / 60)
    #print(f"Found manual trans car: GEARBOX_477 at {frequency}Hz")
    #assert isclose(frequency, 50, abs_tol=5)
    car_results[segment[0]][address] += 1

  if segment_counts[door_address] > 0:
    frequency = round(segment_counts[door_address] / 60)
    #print(f"Found door message: DOORS_OPEN at {frequency}Hz")
    #assert isclose(frequency, 3, abs_tol=1)
    car_results[segment[0]][door_address] += 1

  for scm_address in scm_addresses:
    if segment_counts[scm_address] > 0:
      frequency = round(segment_counts[scm_address] / 60)
      print(f"Found SCM message {scm_address=} at {frequency}Hz")
      car_results[segment[0]][scm_address] += 1

print(f"Analysis finished")
# Out:
# Analyzing segment aa2185702e887680/00000052--e5da04584a/17/s   for HONDA_CRV
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 3f140ce4ed67c267/00000195--7abfcd299a/61/s   for HONDA_CRV
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment aa2185702e887680/00000077--bfe079b3a8/53/s   for HONDA_CRV
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment a4b5df8d28022ac1/00000000--7097b5b521/15/s   for HONDA_CRV
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 3f140ce4ed67c267/000001b7--a90a4b676b/32/s   for HONDA_CRV
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment fba0ac10cc1b90ac/00000040--b373054b96/1/s    for ACURA_ILX
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment fba0ac10cc1b90ac/00000024--9ce369fb6c/1/s    for ACURA_ILX
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment fba0ac10cc1b90ac/00000042--226370e09b/1/s    for ACURA_ILX
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment fba0ac10cc1b90ac/00000024--9ce369fb6c/13/s   for ACURA_ILX
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 81ba9f3dd97c128e/00000000--e0c6d9f7d0/1/s    for HONDA_E
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 81ba9f3dd97c128e/00000000--e0c6d9f7d0/2/s    for HONDA_E
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment c37a12b7f8121923/2025-03-11--21-53-24/61/s   for HONDA_CIVIC_BOSCH
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment c37a12b7f8121923/2025-03-11--21-53-24/15/s   for HONDA_CIVIC_BOSCH
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment c37a12b7f8121923/2025-03-11--21-53-24/19/s   for HONDA_CIVIC_BOSCH
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment c37a12b7f8121923/2025-03-11--21-53-24/64/s   for HONDA_CIVIC_BOSCH
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 3339c2f5af24e33b/2025-06-06--09-32-22/8/s    for HONDA_CIVIC_BOSCH
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 670050f7f6a10422/000000ed--57899a5803/2/s    for ACURA_RDX_3G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment fb5c5b77346c374b/00000079--add0c156e8/10/s   for ACURA_RDX_3G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment f8d72ec3768bc1f1/00000296--f5cdb4d8c6/4/s    for ACURA_RDX_3G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 1a3babf02776691a/000004a5--bdbaf41e77/3/s    for ACURA_RDX_3G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 33f302914a6ca6a5/000003c3--6177f67faf/99/s   for ACURA_RDX_3G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 78edb6a9a06e891d/00000221--2e87816243/1/s    for HONDA_HRV
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 78edb6a9a06e891d/00000279--99308373a2/3/s    for HONDA_HRV
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 6e9442a1c18f2abd/000004a9--d743b5e2cd/11/s   for HONDA_HRV
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 6e9442a1c18f2abd/00000514--6cb0ca3a0a/13/s   for HONDA_HRV
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 78edb6a9a06e891d/000001eb--7a3494de4f/11/s   for HONDA_HRV
# Found SCM message scm_address=660 at 23Hz
# Found SCM message scm_address=422 at 47Hz
# Analyzing segment bbde27b9fb22f84b/00000042--68792fbabb/7/s    for HONDA_INSIGHT
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment f7d92a003486dc37/000004ae--5d91723681/101/s  for HONDA_INSIGHT
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 3d2636872920366d/0000000c--305baf7cf8/32/s   for HONDA_INSIGHT
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment f7d92a003486dc37/00000456--31e10c43ec/16/s   for HONDA_INSIGHT
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 46ed1f05072e029a/00000057--69dfed953a/36/s   for HONDA_INSIGHT
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment f77dffd74248543d/2025-03-31--06-44-20/111/s  for HONDA_ODYSSEY
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment f77dffd74248543d/2025-05-04--05-43-22/118/s  for HONDA_ODYSSEY
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment a3636d74d9353700/2025-05-20--17-37-24/22/s   for HONDA_ODYSSEY
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 13c258a29d411653/2025-06-07--06-35-37/10/s   for HONDA_ODYSSEY
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment f77dffd74248543d/2025-05-04--23-08-28/20/s   for HONDA_ODYSSEY
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 6354b3a74b9ac09d/000003a1--153baa4fbb/301/s  for ACURA_RDX
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 792026eae0677c79/00000002--89c18b30d9/17/s   for ACURA_RDX
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 6354b3a74b9ac09d/000003a1--153baa4fbb/294/s  for ACURA_RDX
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 6354b3a74b9ac09d/000003a1--153baa4fbb/281/s  for ACURA_RDX
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 19ce0c38fbb898ae/00000198--fc9d529619/10/s   for ACURA_RDX
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 38d0b7ab68b64338/000005fb--8e5899c431/7/s    for HONDA_FREED
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 38d0b7ab68b64338/0000065f--cee09e1df3/10/s   for HONDA_FREED
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 38d0b7ab68b64338/00000658--4729a2bfe0/11/s   for HONDA_FREED
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 38d0b7ab68b64338/000005f2--fb615c5c77/13/s   for HONDA_FREED
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 38d0b7ab68b64338/00000637--7203e40a60/5/s    for HONDA_FREED
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 22a0ad68fe420dad/00000007--0e5b91fc77/37/s   for HONDA_CIVIC
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 43799248fe2b14c4/0000008b--da212027ae/3/s    for HONDA_CIVIC
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 0945b6c6b3ebaa9f/00000091--7de98983d3/20/s   for HONDA_CIVIC
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 7528525a29a9d9e6/000005f3--0e12e3af68/1/s    for HONDA_CIVIC
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 870f264b7df72bed/00000417--38a0e02230/72/s   for HONDA_CIVIC
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 445d1ade497345f3/0000010c--b60f52f210/10/s   for HONDA_FIT
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment df67bf140583e302/00000118--e5d48ebb52/33/s   for HONDA_FIT
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment df67bf140583e302/00000131--1be56fff91/25/s   for HONDA_FIT
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment df67bf140583e302/00000116--e8a5918910/13/s   for HONDA_FIT
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 4d247d5337a9f864/00000413--aa273c86f5/85/s   for HONDA_FIT
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 251122482046c71b/00000425--ec4af468bb/11/s   for HONDA_CIVIC_2022
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 251122482046c71b/00000425--ec4af468bb/8/s    for HONDA_CIVIC_2022
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 63d289c9b8af52b6/00000033--bf038642d4/7/s    for HONDA_CIVIC_2022
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 9ebedac9dc7ce652/0000009b--dcbba60b55/84/s   for HONDA_CIVIC_2022
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 94a7f3fcd6a2e164/00000017--617e218eb1/107/s  for HONDA_CIVIC_2022
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment d360e36bf258dcd8/0000057e--14793e1b4d/11/s   for HONDA_CRV_5G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment a72482b4766832e9/00000004--2438333243/5/s    for HONDA_CRV_5G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment b4f79d4e97360586/00000576--ce5e32a24e/15/s   for HONDA_CRV_5G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment a72482b4766832e9/00000004--2438333243/22/s   for HONDA_CRV_5G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment dac2ce5a5c902be6/00000162--b2e59445a4/7/s    for HONDA_CRV_5G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment b3a1a214664b7d31/2025-06-06--16-58-12/10/s   for HONDA_ACCORD
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment b3a1a214664b7d31/2025-07-03--15-37-58/10/s   for HONDA_ACCORD
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment b3a1a214664b7d31/2025-04-19--19-31-39/12/s   for HONDA_ACCORD
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment b3a1a214664b7d31/2025-05-31--08-55-18/11/s   for HONDA_ACCORD
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment b3a1a214664b7d31/2025-06-17--00-52-26/2/s    for HONDA_ACCORD
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 1ed62b77f748420f/2025-04-24--09-36-44/2/s    for HONDA_RIDGELINE
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 1ed62b77f748420f/2025-05-20--08-05-49/9/s    for HONDA_RIDGELINE
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 1ed62b77f748420f/2025-05-26--14-52-25/27/s   for HONDA_RIDGELINE
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 1ed62b77f748420f/2025-05-11--12-27-25/4/s    for HONDA_RIDGELINE
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 1ed62b77f748420f/2025-05-11--12-27-25/11/s   for HONDA_RIDGELINE
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment d6c98b1ebf9916b9/00000039--4da3584f42/10/s   for HONDA_CRV_HYBRID
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 01e8fddfa60aae68/00000052--c3d5b35af9/16/s   for HONDA_CRV_HYBRID
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 8f3f4683d7cfda74/000002ed--a69d645670/1/s    for HONDA_CRV_HYBRID
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment fde53c3c109fb4c0/00000045--630491c2e7/16/s   for HONDA_CRV_HYBRID
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 93fa8effd6b5b3ee/00000552--14ac9c2d13/6/s    for HONDA_CRV_HYBRID
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment adc4a7c670779ee7/00000072--2ed02bd162/20/s   for HONDA_PILOT
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 177b1675a5e94d48/00000668--c07f890026/5/s    for HONDA_PILOT
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 216172f653b1fb30/0000007a--6c1e88a291/2/s    for HONDA_PILOT
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 8a9bfee29c5a277a/00000109--6849eb8ce7/35/s   for HONDA_PILOT
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment b168dde5f920d11a/00000043--120e919ec8/2/s    for HONDA_PILOT
# Found SCM message scm_address=660 at 25Hz
# Found SCM message scm_address=422 at 50Hz
# Analyzing segment 9662a1dab70c9dc3/00000000--f8bf47be5d/0/s    for HONDA_PILOT_4G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 26Hz
# Analyzing segment 9662a1dab70c9dc3/00000000--f8bf47be5d/4/s    for HONDA_PILOT_4G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment b645d75fb51020ca/00000000--46725055e1/1/s    for HONDA_HRV_3G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment c28ee1100a35e353/0000004e--d5b5b51226/10/s   for HONDA_HRV_3G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment c28ee1100a35e353/00000050--b76985a107/24/s   for HONDA_HRV_3G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment c28ee1100a35e353/00000050--b76985a107/11/s   for HONDA_HRV_3G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment be09ebdbc03705f0/00000000--19a6d7da6d/18/s   for HONDA_HRV_3G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment f9c43864cf057d05|2024-01-15--23-01-20/0      for ACURA_MDX_4G
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 26Hz
# Analyzing segment 3f8ae015ce70365f/00000003--a22590d0e4/0      for ACURA_INTEGRA
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 25Hz
# Analyzing segment 56b2cf1dacdcd033/00000048--3267801001/0      for HONDA_CITY
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 26Hz
# Analyzing segment ad9840558640c31d/0000001a--d6cd4871c2/0      for ACURA_MDX_4G_MMR
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 26Hz
# Analyzing segment 0416c2843c0bfc91/0000001d--59c7744d87/0      for ACURA_RDX_3G_MMR
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# Found SCM message scm_address=660 at 2Hz
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 26Hz
# Analyzing segment 414af83891dbf72c/00000006--51fa6d99cd/0      for HONDA_NBOX
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# 622 length 8
# Found SCM message scm_address=660 at 1Hz
# Found SCM message scm_address=806 at 10Hz
# Found SCM message scm_address=662 at 26Hz
# Analysis finished

# %%
print(f"Gear messages by platform      0x188 0x191 0x1A3 0x1DD 0x405   0x294 0x1A6 0x326 0x296")
print(f"------------------------------ ----- ----- ----- ----- -----   ----- ----- ----- -----")
for platform in sorted(car_results):
  print(f"{platform:30} {car_results[platform][392]:5} {car_results[platform][401]:5} {car_results[platform][419]:5} {car_results[platform][477]:5} {car_results[platform][1029]:5}" + \
                      f"{car_results[platform][660]:5} {car_results[platform][422]:5} {car_results[platform][806]:5} {car_results[platform][662]:5}")
# Out:
# Gear messages by platform      0x188 0x191 0x1A3 0x1DD 0x405   0x294 0x1A6 0x326 0x296
# ------------------------------ ----- ----- ----- ----- -----   ----- ----- ----- -----
# ACURA_ILX                          0     0     4     0     4    4     4     0     0
# ACURA_INTEGRA                      0     1     0     0     0    0     0     1     1
# ACURA_MDX_4G                       0     0     1     0     0    0     0     1     1
# ACURA_MDX_4G_MMR                   0     0     1     0     0    0     0     1     1
# ACURA_RDX                          5     0     0     0     5    5     5     0     0
# ACURA_RDX_3G                       0     0     5     0     0    0     0     5     5
# ACURA_RDX_3G_MMR                   0     0     0     0     0    0     0     0     0
# HONDA_ACCORD                       0     5     0     0     0    0     0     5     5
# HONDA_CITY                         0     1     0     0     0    0     0     1     1
# HONDA_CIVIC                        0     5     0     0     5    0     0     5     5
# HONDA_CIVIC_2022                   0     3     2     0     0    0     0     5     5
# HONDA_CIVIC_BOSCH                  0     5     0     0     1    0     0     5     5
# HONDA_CRV                          0     5     0     0     5    5     5     0     0
# HONDA_CRV_5G                       0     5     0     0     5    0     0     5     5
# HONDA_CRV_HYBRID                   0     0     5     0     0    0     0     5     5
# HONDA_E                            0     0     2     0     0    0     0     2     2
# HONDA_FIT                          0     5     0     0     5    5     5     0     0
# HONDA_FREED                        0     5     0     0     0    5     5     0     0
# HONDA_HRV                          0     5     0     0     0    5     5     0     0
# HONDA_HRV_3G                       0     5     0     0     0    0     0     5     5
# HONDA_INSIGHT                      0     0     5     0     5    0     0     5     5
# HONDA_NBOX                         0     0     0     0     0    0     0     0     0
# HONDA_ODYSSEY                      0     0     5     0     5    0     0     5     5
# HONDA_PILOT                        1     0     5     0     5    5     5     0     0
# HONDA_PILOT_4G                     0     0     2     0     0    0     0     2     2
# HONDA_RIDGELINE                    0     0     5     0     5    5     5     0     0
